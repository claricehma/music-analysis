# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.bar(["NN", "KNN", "XGB"], [84.62, 73.44, 73.96], color=["indianred","royalblue","mediumseagreen"])
plt.title("Model Accuracy")
plt.xlabel("Model")
plt.ylabel("Accuracy %")
plt.show()
