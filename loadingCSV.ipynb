# %%
"""from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# bach, beethoven, brahms, cambini, dvorak, faure, hadyn, mozart, ravel, schubert
df = pd.read_csv('train_data.csv')

names = ['bach', 'beethoven', 'brahms', 'cambini', 'dvorak', 'faure', 'haydn', 'mozart', 'ravel', 'schubert']
csvs =  ['bach.csv', 'beethoven.csv', 'brahms.csv', 'cambini.csv', 'dvorak.csv', 'faure.csv', 'haydn.csv', 'mozart.csv', 'ravel.csv', 'schubert.csv']

for i in range(0, 10):
    df_filtered = df[df['composer'].str.strip().str.lower() == names[i]]
    df_filtered.to_csv(csvs[i], index=False)

print("done")
"""
# Out:
# 'from pathlib import Path\nimport pandas as pd\nimport matplotlib.pyplot as plt\nimport seaborn as sns\n\n# bach, beethoven, brahms, cambini, dvorak, faure, hadyn, mozart, ravel, schubert\ndf = pd.read_csv(\'train_data.csv\')\n\nnames = [\'bach\', \'beethoven\', \'brahms\', \'cambini\', \'dvorak\', \'faure\', \'haydn\', \'mozart\', \'ravel\', \'schubert\']\ncsvs =  [\'bach.csv\', \'beethoven.csv\', \'brahms.csv\', \'cambini.csv\', \'dvorak.csv\', \'faure.csv\', \'haydn.csv\', \'mozart.csv\', \'ravel.csv\', \'schubert.csv\']\n\nfor i in range(0, 10):\n    df_filtered = df[df[\'composer\'].str.strip().str.lower() == names[i]]\n    df_filtered.to_csv(csvs[i], index=False)\n\nprint("done")\n'

# %%
import pandas as pd

df = pd.read_csv("test_data.csv")

new_column_data = ['Bach', 'Haydn', 'Beethoven', 'Beethoven','Beethoven', 'Bach', 'Mozart','Bach','Beethoven','Schubert']
new_column_data2 = [0, 6, 1, 1, 1, 0, 7, 0, 1, 9]
df.insert(loc=1, column="composer", value=new_column_data)
df.insert(loc=2, column="composer_label", value=new_column_data2)
df.to_csv('test_data_composers.csv', index=False)

# %%
import pandas as pd

df = pd.read_csv('test_data_composers.csv')

df = df.drop(columns=['composer'])

df.to_csv('test_data_clean.csv', index=False)

print("done!")
# Out:
# done!
